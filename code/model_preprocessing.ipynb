# %% [markdown]
# # Preprocessing of the metabolic model of Sulfolobus solfataricus
#
# Author: Diana Szeliova \
# Last update: 15.7.2024
#
# * Sulfolobus solfataricus model from https://doi.org/10.1111/mmi.13498 downloaded from https://fairdomhub.org/models/225
# * rename metabolites and reactions so that they subscribe to cobrapy standards
# * add missing reactions

# %%
import cobra
import re
import pickle
import pandas as pd
from cobra import Reaction

# %%
modelname = "Sulfolobus-solfataricus_D-glucose.xml"
model = cobra.io.sbml.validate_sbml_model(f"../data/{modelname}")
# Out:
# SBML errors in validation, check error log for details.
# COBRA errors in validation, check error log for details.
# COBRA warnings in validation, check error log for details.

# %% [markdown]
# ### Find reaction and metabolite IDs in the SBML file

# %%
metabolite_ids = []
reaction_ids = []
with open(f"../data/{modelname}") as file:
    lines = file.readlines()

    # get lists of metabolite and reaction ids
    for line in lines:
        try:
            metabolite_ids.append(re.search('<species(.*)id="(.*)" name', line).group(2))
        except AttributeError:
            pass

        try:
            reaction_ids.append(re.search('<reaction id="(.*)" name', line).group(1))
        except AttributeError:
            pass

# %% [markdown]
# ### Rename metabolite and reaction IDs to numbers

# %%
new_metabolite_ids = {f"M_{idx}": old_id for idx, old_id in enumerate(metabolite_ids)}
new_reaction_ids = {f"R_{idx}": old_id for idx, old_id in enumerate(reaction_ids)}

# %%
# replace old ids with new ids
new_lines = []
for line in lines:
    for new_id, old_id in new_metabolite_ids.items():
        if f'"{old_id}"' in line:
            line = line.replace(old_id, new_id)

    for new_id, old_id in new_reaction_ids.items():
        if f'"{old_id}"' in line:
            line = line.replace(old_id, new_id)

    if "<listOfProducts/>" in line or "<notes/>" in line:
        continue
    new_lines.append(line)

# %% [markdown]
# ### Other corrections

# %%
new_lines[1] = '<sbml level="2" version="4" xmlns="http://www.sbml.org/sbml/level2/version4" xmlns:html="http://www.w3.org/1999/xhtml">'

# %%
new_lines[2] = new_lines[2].replace("Unnamed model - D-glucose", "Sulfolobus")

# %% [markdown]
# ### Write the model, them read it again

# %%
new_modelname = "Sulfolobus-solfataricus_corrected"
with open(f"../data/{new_modelname}.xml", "w") as file:
    for line in new_lines:
        file.write(line)

# %%
model = cobra.io.sbml.validate_sbml_model(f"../data/{new_modelname}.xml")
# Out:
# COBRA warnings in validation, check error log for details.

# %%
model = cobra.io.read_sbml_model(f"../data/{new_modelname}.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_0 "R_0">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_1 "R_1">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_2 "R_2">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_3 "R_3">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_4 "R_4">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_4 "R_4">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_5 "R_5">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_5 "R_5">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_6 "R_6">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_6 "R_6">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction R_7 "R_7">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_7 "R_7">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction R_8 "R_8">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_8 "R_8">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_9 "R_9">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_9 "R_9">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction R_10 "R_10">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_10 "R_10">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_11 "R_11">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_11 "R_11">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_12 "R_12">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_12 "R_12">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_13 "R_13">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_13 "R_13">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_14 "R_14">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_14 "R_14">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_15 "R_15">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_15 "R_15">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_16 "R_16">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R_16 "R_16">'
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_17 "R_17">
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction R

# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_904 "R_904">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_905 "R_905">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_906 "R_906">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_907 "R_907">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_908 "R_908">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_909 "R_909">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_910 "R_910">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_911 "R_911">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_912 "R_912">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_913 "R_913">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_914 "R_914">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_915 "R_915">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_916 "R_916">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_917 "R_917">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_918 "R_918">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_919 "R_919">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_920 "R_920">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_921 "R_921">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_922 "R_922">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_923 "R_923">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_924 "R_924">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_925 "R_925">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_926 "R_926">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_927 "R_927">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_928 "R_928">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_929 "R_929">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_930 "R_930">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_931 "R_931">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_932 "R_932">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_933 "R_933">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_934 "R_934">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_935 "R_935">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_936 "R_936">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_937 "R_937">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_938 "R_938">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_939 "R_939">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_940 "R_940">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_941 "R_941">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_942 "R_942">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_943 "R_943">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_944 "R_944">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_945 "R_945">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_946 "R_946">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_947 "R_947">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_948 "R_948">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_949 "R_949">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_950 "R_950">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_951 "R_951">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_952 "R_952">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_953 "R_953">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_954 "R_954">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_955 "R_955">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_956 "R_956">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_957 "R_957">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_958 "R_958">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_959 "R_959">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_960 "R_960">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_961 "R_961">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_962 "R_962">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_963 "R_963">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_964 "R_964">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_965 "R_965">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_966 "R_966">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_967 "R_967">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_968 "R_968">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_969 "R_969">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_970 "R_970">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_971 "R_971">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_972 "R_972">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_973 "R_973">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_974 "R_974">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_975 "R_975">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_976 "R_976">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_977 "R_977">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_978 "R_978">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_979 "R_979">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_980 "R_980">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_981 "R_981">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_982 "R_982">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_983 "R_983">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_984 "R_984">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_985 "R_985">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_986 "R_986">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_987 "R_987">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_988 "R_988">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_989 "R_989">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_990 "R_990">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_991 "R_991">
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.

# %% [markdown]
# ### Other model changes
# * add lysine exchange reaction

# %%
# add secretion for lysine
reaction = Reaction(f"{len(new_reaction_ids)}")
reaction.name = reaction.id
reaction.lower_bound = 0.
reaction.upper_bound = 1000.
reaction.add_metabolites({model.metabolites.get_by_id("10"): -1})
model.add_reactions([reaction])

# %%
reaction
# Out:
# <Reaction 992 at 0x7f3e64bb4d00>

# %%
new_reaction_ids[f"R_{reaction.id}"] = "T_flux_L-lysine"

# %%
with open('../data/sulfolobus_metabolite_ids.pkl', 'wb') as fp:
    pickle.dump(new_metabolite_ids, fp)

with open('../data/sulfolobus_reaction_ids.pkl', 'wb') as fp:
    pickle.dump(new_reaction_ids, fp)

# %% [markdown]
# ## Rename metabolites and reactions (for plotting)

# %%
node_names = pd.read_csv("../data/node_names_escher.csv")
node_names = node_names.drop_duplicates()
node_names['node'] = node_names['node'].astype(str)
node_dict = dict(zip(node_names.node, node_names.short_name))

# %%
for metabolite in model.metabolites:
    try:
        metabolite.name = node_dict[metabolite.id]
    except KeyError:
        continue

# %%
for reaction in model.reactions:
    reaction.name = ""

# %% [markdown]
# ### Write the model and test if it can be read without problems

# %%
# save as json for escher
cobra.io.save_json_model(model, f"../data/{new_modelname}.json")

# %%
cobra.io.write_sbml_model(model, f"../data/{new_modelname}.xml")

# %%
# test if model can be read without problems
model = cobra.io.read_sbml_model(f"../data/{new_modelname}.xml")

# %%
model
# Out:
# <Model Sulfolobus at 0x7f3e64b5fa90>
